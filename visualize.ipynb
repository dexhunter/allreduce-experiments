# %% [markdown]
# # Visualize Experiment Results

# %%
# !pip install matplotlib
# !pip install numpy
# !pip install pandas

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Power of 2
#
# Algo 1 Basic Linear
#
# 2 CPU
# ```
# # OSU MPI Allreduce Latency Test v5.7
# # Size       Avg Latency(us)
# 4                       0.53
# 8                       0.53
# 16                      0.54
# 32                      0.54
# 64                      0.59
# 128                     0.65
# 256                     0.74
# 512                     1.15
# 1024                    1.38
# 2048                    1.87
# 4096                    6.17
# 8192                    8.45
# 16384                  13.60
# 32768                  19.71
# 65536                  33.41
# 131072                 66.15
# 262144                126.59
# 524288                234.18
# 1048576               453.82
# 2097152              1363.16
# 4194304              4409.98
# 8388608              9224.25
# 16777216            18018.56
# 33554432            35583.43
# 67108864            71186.11
# 134217728          141502.59
# 268435456          282152.26
# 536870912          563424.36
# 1073741824        1126751.72
# ```

# %% [markdown]
# Algo 2 Non-overlapping
#
# 2 CPU
# ```
# # OSU MPI Allreduce Latency Test v5.7
# # Size       Avg Latency(us)
# 4                       0.51
# 8                       0.55
# 16                      0.54
# 32                      0.55
# 64                      0.56
# 128                     0.68
# 256                     0.74
# 512                     1.13
# 1024                    1.40
# 2048                    1.94
# 4096                    6.24
# 8192                    9.11
# 16384                  14.41
# 32768                  19.96
# 65536                  35.00
# 131072                 65.58
# 262144                126.89
# 524288                238.36
# 1048576               479.84
# 2097152              1485.02
# 4194304              4421.62
# 8388608              9546.80
# 16777216            18716.78
# 33554432            36885.50
# 67108864            74172.34
# 134217728          144295.67
# 268435456          284027.75
# 536870912          566515.38
# 1073741824        1135576.44
# ```

# %% [markdown]
# Algo 3 Recursive Doubling
#
# 2 CPU
#
# ```
# # OSU MPI Allreduce Latency Test v5.7
# # Size       Avg Latency(us)
# 4                       0.58
# 8                       0.54
# 16                      0.56
# 32                      0.56
# 64                      0.61
# 128                     0.68
# 256                     0.77
# 512                     1.20
# 1024                    1.40
# 2048                    1.91
# 4096                    6.36
# 8192                    8.76
# 16384                  14.03
# 32768                  20.38
# 65536                  34.15
# 131072                 65.87
# 262144                129.30
# 524288                237.93
# 1048576               460.90
# 2097152              1369.40
# 4194304              4357.07
# 8388608              9458.90
# 16777216            18945.31
# 33554432            37671.15
# 67108864            73077.13
# 134217728          142493.19
# 268435456          283057.09
# 536870912          565414.31
# 1073741824        1133058.50
# ```

# %% [markdown]
# Algo 4 Ring
#
# 2 CPU
# ```
# # OSU MPI Allreduce Latency Test v5.7
# # Size       Avg Latency(us)
# 4                       0.51
# 8                       0.55
# 16                      0.55
# 32                      0.55
# 64                      0.57
# 128                     0.67
# 256                     0.75
# 512                     1.13
# 1024                    1.38
# 2048                    1.90
# 4096                    6.14
# 8192                    8.39
# 16384                  13.38
# 32768                  19.51
# 65536                  33.23
# 131072                 65.94
# 262144                125.64
# 524288                233.22
# 1048576               447.55
# 2097152              1309.58
# 4194304              4431.89
# 8388608              9256.11
# 16777216            18294.04
# 33554432            36100.40
# 67108864            71668.39
# 134217728          142204.49
# 268435456          283792.18
# 536870912          565889.29
# 1073741824        1128262.47
# ```

# %% [markdown]
# Algo 5 Segmented Ring
#
# 2 CPU
#
# ```
# # OSU MPI Allreduce Latency Test v5.7
# # Size       Avg Latency(us)
# 4                       0.58
# 8                       0.54
# 16                      0.55
# 32                      0.60
# 64                      0.57
# 128                     0.67
# 256                     0.80
# 512                     1.17
# 1024                    1.41
# 2048                    1.89
# 4096                    6.25
# 8192                    8.64
# 16384                  13.57
# 32768                  19.64
# 65536                  33.55
# 131072                 66.01
# 262144                128.39
# 524288                234.69
# 1048576               465.68
# 2097152              1480.13
# 4194304              4466.71
# 8388608              9576.09
# 16777216            18471.66
# 33554432            36813.51
# 67108864            71623.21
# 134217728          142365.74
# 268435456          282701.11
# 536870912          564823.46
# 1073741824        1128065.95
# ```

# %% [markdown]
# Algo 6 Rabenseifner
#
#
# 2 CPU
# ```
# # OSU MPI Allreduce Latency Test v5.7
# # Size       Avg Latency(us)
# 4                       0.54
# 8                       0.56
# 16                      0.59
# 32                      0.56
# 64                      0.59
# 128                     0.67
# 256                     0.76
# 512                     1.16
# 1024                    1.46
# 2048                    1.87
# 4096                    6.41
# 8192                    8.67
# 16384                  13.88
# 32768                  20.32
# 65536                  35.03
# 131072                 66.41
# 262144                128.81
# 524288                238.53
# 1048576               465.61
# 2097152              1447.64
# 4194304              4450.26
# 8388608              9464.69
# 16777216            18713.50
# 33554432            37131.67
# 67108864            73343.12
# 134217728          143626.24
# 268435456          286386.16
# 536870912          569032.53
# 1073741824        1134912.85
# ```

# %% [markdown]
# # Non Power of 2
#
# Algo 1 Basic Linear
#
# 2 CPU
#
# ```
# # OSU MPI Allreduce Latency Test v5.7
# # Size       Avg Latency(us)
# 4                       0.50
# 20                      0.54
# 100                     0.59
# 500                     1.17
# 2500                    2.16
# 12500                  12.70
# 62500                  32.98
# 312500                148.16
# 1562500               762.35
# 7812500              8675.72
# 39062500            41731.77
# 195312500          206829.38
# 976562500         1027035.49
# ```

# %% [markdown]
# Algo 2 Non-overlapping
#
# 2 CPU
#
# ```
# # OSU MPI Allreduce Latency Test v5.7
# # Size       Avg Latency(us)
# 4                       0.54
# 20                      0.68
# 100                     0.67
# 500                     1.14
# 2500                    2.24
# 12500                  13.25
# 62500                  34.36
# 312500                151.48
# 1562500               872.15
# 7812500              8891.01
# 39062500            43082.21
# 195312500          211039.65
# 976562500         1038137.84
# ```

# %% [markdown]
# Algo 3 Recursive Doubling
#
# 2 CPU
#
# ```
# # OSU MPI Allreduce Latency Test v5.7
# # Size       Avg Latency(us)
# 4                       0.58
# 20                      0.56
# 100                     0.64
# 500                     1.20
# 2500                    2.21
# 12500                  12.90
# 62500                  32.85
# 312500                155.01
# 1562500               838.92
# 7812500              8733.05
# 39062500            41951.16
# 195312500          206693.36
# 976562500         1029687.24
# ```

# %% [markdown]
# Algo 4 Ring
#
# 2 CPU
#
# ```
# # OSU MPI Allreduce Latency Test v5.7
# # Size       Avg Latency(us)
# 4                       0.52
# 20                      0.56
# 100                     0.61
# 500                     1.19
# 2500                    2.19
# 12500                  13.37
# 62500                  40.13
# 312500                156.15
# 1562500               826.10
# 7812500              9002.85
# 39062500            43788.59
# 195312500          214718.57
# 976562500         1032544.82
# ```

# %% [markdown]
# Algo 5 Segmented Ring
#
# 2 CPU
# ```
# # OSU MPI Allreduce Latency Test v5.7
# # Size       Avg Latency(us)
# 4                       0.57
# 20                      0.61
# 100                     0.64
# 500                     1.24
# 2500                    2.24
# 12500                  12.99
# 62500                  33.94
# 312500                154.39
# 1562500               859.19
# 7812500              8870.10
# 39062500            43543.40
# 195312500          210318.70
# 976562500         1031454.48
# ```

# %% [markdown]
# Algo 6 Rabenseifner
#
# 2 CPU
# ```
# # OSU MPI Allreduce Latency Test v5.7
# # Size       Avg Latency(us)
# 4                       0.55
# 20                      0.56
# 100                     0.63
# 500                     1.15
# 2500                    2.13
# 12500                  12.91
# 62500                  33.20
# 312500                150.28
# 1562500               801.11
# 7812500              9084.03
# 39062500            43375.54
# 195312500          206705.74
# 976562500         1028751.11
# ```

# %%
def read_algo(filename):
    x = []
    y = []

    with open(filename) as f:
        for line in f:
            num = line.split()
            x.append(num[0])
            y.append(num[1])

    x = np.array(x)
    y = np.array(y)

    return x.astype('float'), y.astype('float')

x, y1 = read_algo('data/2cpu/non-power-of-2/algo1.txt')
_, y2 = read_algo('data/2cpu/non-power-of-2/algo2.txt')
_, y3 = read_algo('data/2cpu/non-power-of-2/algo3.txt')
_, y4 = read_algo('data/2cpu/non-power-of-2/algo4.txt')
_, y5 = read_algo('data/2cpu/non-power-of-2/algo5.txt')
_, y6 = read_algo('data/2cpu/non-power-of-2/algo6.txt')

plt.title('Different Allreduce Algorithms among 2 CPUs (size increases non-power-of-two)')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x, y1, label='algo1', marker=11)
plt.plot(x, y2, label='algo2', marker=11)
plt.plot(x, y3, label='algo3', marker=11)
plt.plot(x, y4, label='algo4', marker=11)
plt.plot(x, y5, label='algo5', marker=11)
plt.plot(x, y6, label='algo6', marker=11)

plt.legend()

# %%
plt.show()

# %%
df = pd.DataFrame({'x':x, 'basic_linear': y1, 'nonoverlapping': y2, 'recursive_doubling': y3, 'ring': y4, 'segmented_ring': y5, 'rabenseifner': y6})

# print(df)
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')
plt.title('Different Allreduce Algorithms among 2 CPUs (size increases non-power-of-two)')

# style
plt.style.use('seaborn-darkgrid')
 
# create a color palette
palette = plt.get_cmap('Set1')

# multiple line plot

num=0
for column in df.drop('x', axis=1):
    num+=1
    plt.plot(df['x'], df[column], marker=11, color=palette(num), linewidth=1, alpha=0.9, label=column)

# plt.xlim(9.70*1e8, 9.78*1e8)
# plt.ylim(1.015*1e6, 1.04*1e6)

plt.legend()

# %%
plt.show()

# %%
# non-power-of-two 2 cpu
print(df)

# %%
x, y1 = read_algo('data/2cpu/power-of-2/algo1.txt')
_, y2 = read_algo('data/2cpu/power-of-2/algo2.txt')
_, y3 = read_algo('data/2cpu/power-of-2/algo3.txt')
_, y4 = read_algo('data/2cpu/power-of-2/algo4.txt')
_, y5 = read_algo('data/2cpu/power-of-2/algo5.txt')
_, y6 = read_algo('data/2cpu/power-of-2/algo6.txt')

plt.title('Different Allreduce Algorithms among 2 CPUs')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

df = pd.DataFrame({'x':x, 'basic_linear': y1, 'nonoverlapping': y2, 'recursive_doubling': y3, 'ring': y4, 'segmented_ring': y5, 'rabenseifner': y6})

# print(df)
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')
plt.title('Different Allreduce Algorithms among 2 CPUs (size increases power-of-two)')

# style
plt.style.use('seaborn-darkgrid')
 
# create a color palette
palette = plt.get_cmap('Set1')

# multiple line plot

num=0
for column in df.drop('x', axis=1):
    num+=1
    plt.plot(df['x'], df[column], marker=11, color=palette(num), linewidth=1, alpha=0.9, label=column)

# plt.xlim(9.70*1e8, 9.78*1e8)
# plt.ylim(1.015*1e6, 1.04*1e6)

plt.legend()

# %%
plt.show()

# %%
# power-of-two 2 cpu
print(df)

# %%
x1, y1 = read_algo('data/2cpu/power-of-2/algo1.txt')
x2, y2 = read_algo('data/2cpu/non-power-of-2/algo1.txt')

plt.title('Basic Linear (Different Message Size) among 2 CPUs')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x1, y1, label='power-of-2', marker=11)
plt.plot(x2, y2, label='non-power-of-2', marker=11)

# plt.xlim(9.70*1e8, 9.78*1e8)
# plt.ylim(1.015*1e6, 1.04*1e6)
plt.legend()

plt.show()

# %%
x1, y1 = read_algo('data/2cpu/power-of-2/algo2.txt')
x2, y2 = read_algo('data/2cpu/non-power-of-2/algo2.txt')

plt.title('Non-overlapping (Different Message Size) among 2 CPUs')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x1, y1, label='power-of-2', marker=11)
plt.plot(x2, y2, label='non-power-of-2', marker=11)

# plt.xlim(9.70*1e8, 9.78*1e8)
# plt.ylim(1.015*1e6, 1.04*1e6)
plt.legend()

plt.show()

# %%
x1, y1 = read_algo('data/2cpu/power-of-2/algo3.txt')
x2, y2 = read_algo('data/2cpu/non-power-of-2/algo3.txt')

plt.title('Recursive Doubling (Different Message Size) among 2 CPUs')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x1, y1, label='power-of-2', marker=11)
plt.plot(x2, y2, label='non-power-of-2', marker=11)

# plt.xlim(9.70*1e8, 9.78*1e8)
# plt.ylim(1.015*1e6, 1.04*1e6)
plt.legend()

plt.show()

# %%
x1, y1 = read_algo('data/2cpu/power-of-2/algo4.txt')
x2, y2 = read_algo('data/2cpu/non-power-of-2/algo4.txt')

plt.title('Ring (Different Message Size) among 2 CPUs')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x1, y1, label='power-of-2', marker=11)
plt.plot(x2, y2, label='non-power-of-2', marker=11)

# plt.xlim(9.70*1e8, 9.78*1e8)
# plt.ylim(1.015*1e6, 1.04*1e6)
plt.legend()

plt.show()

# %%
x1, y1 = read_algo('data/2cpu/power-of-2/algo5.txt')
x2, y2 = read_algo('data/2cpu/non-power-of-2/algo5.txt')

plt.title('Segmented Ring (Different Message Size) among 2 CPUs')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x1, y1, label='power-of-2', marker=11)
plt.plot(x2, y2, label='non-power-of-2', marker=11)

# plt.xlim(9.70*1e8, 9.78*1e8)
# plt.ylim(1.015*1e6, 1.04*1e6)
plt.legend()

plt.show()

# %%
x1, y1 = read_algo('data/2cpu/power-of-2/algo6.txt')
x2, y2 = read_algo('data/2cpu/non-power-of-2/algo6.txt')

plt.title('Rabenseifner (Different Message Size) among 2 CPUs')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x1, y1, label='power-of-2', marker=11)
plt.plot(x2, y2, label='non-power-of-2', marker=11)

# plt.xlim(9.70*1e8, 9.78*1e8)
# plt.ylim(1.015*1e6, 1.04*1e6)
plt.legend()

plt.show()

# %%
x1, y1 = read_algo('data/16cpu/power-of-2/algo1.txt')
x2, y2 = read_algo('data/16cpu/non-power-of-2/algo1.txt')

plt.title('Basic Linear (Different Message Size) among 16 CPUs')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x1, y1, label='power-of-2', marker=11)
plt.plot(x2, y2, label='non-power-of-2', marker=11)

# plt.xlim(9.70*1e8, 9.78*1e8)
# plt.ylim(1.015*1e6, 1.04*1e6)
plt.legend()
plt.savefig('imgs/16cpu-algo1.png')

plt.show()

# %%
x1, y1 = read_algo('data/16cpu/power-of-2/algo2.txt')
x2, y2 = read_algo('data/16cpu/non-power-of-2/algo2.txt')

plt.title('Non Overlapping (Different Message Size) among 16 CPUs')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x1, y1, label='power-of-2', marker=11)
plt.plot(x2, y2, label='non-power-of-2', marker=11)

# plt.xlim(9.70*1e8, 9.78*1e8)
# plt.ylim(1.015*1e6, 1.04*1e6)
plt.legend()
plt.savefig('imgs/16cpu-algo2.png')

plt.show()

# %%
x1, y1 = read_algo('data/16cpu/power-of-2/algo3.txt')
x2, y2 = read_algo('data/16cpu/non-power-of-2/algo3.txt')

plt.title('Recursive Doubling (Different Message Size) among 16 CPUs')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x1, y1, label='power-of-2', marker=11)
plt.plot(x2, y2, label='non-power-of-2', marker=11)

# plt.xlim(9.70*1e8, 9.78*1e8)
# plt.ylim(1.015*1e6, 1.04*1e6)
plt.legend()
plt.savefig('imgs/16cpu-algo3.png')


plt.show()

# %%
x1, y1 = read_algo('data/16cpu/power-of-2/algo4.txt')
x2, y2 = read_algo('data/16cpu/non-power-of-2/algo4.txt')

plt.title('Ring (Different Message Size) among 16 CPUs')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x1, y1, label='power-of-2', marker=11)
plt.plot(x2, y2, label='non-power-of-2', marker=11)

# plt.xlim(9.70*1e8, 9.78*1e8)
# plt.ylim(1.015*1e6, 1.04*1e6)
plt.legend()
plt.savefig('imgs/16cpu-algo4.png')


plt.show()

# %%
x1, y1 = read_algo('data/16cpu/power-of-2/algo5.txt')
x2, y2 = read_algo('data/16cpu/non-power-of-2/algo5.txt')

plt.title('Segmented Ring (Different Message Size) among 16 CPUs')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x1, y1, label='power-of-2', marker=11)
plt.plot(x2, y2, label='non-power-of-2', marker=11)

# plt.xlim(9.70*1e8, 9.78*1e8)
# plt.ylim(1.015*1e6, 1.04*1e6)
plt.legend()
plt.savefig('imgs/16cpu-algo5.png')

plt.show()

# %%
x1, y1 = read_algo('data/16cpu/power-of-2/algo6.txt')
x2, y2 = read_algo('data/16cpu/non-power-of-2/algo6.txt')

plt.title('Rabenseifner (Different Message Size) among 16 CPUs')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x1, y1, label='power-of-2', marker=11)
plt.plot(x2, y2, label='non-power-of-2', marker=11)

# plt.xlim(9.70*1e8, 9.78*1e8)
# plt.ylim(1.015*1e6, 1.04*1e6)
plt.legend()
plt.savefig('imgs/16cpu-algo6.png')

plt.show()

# %%
x, y1 = read_algo('data/16cpu/power-of-2/algo1.txt')
_, y2 = read_algo('data/16cpu/power-of-2/algo2.txt')
_, y3 = read_algo('data/16cpu/power-of-2/algo3.txt')
_, y4 = read_algo('data/16cpu/power-of-2/algo4.txt')
_, y5 = read_algo('data/16cpu/power-of-2/algo5.txt')
_, y6 = read_algo('data/16cpu/power-of-2/algo6.txt')

plt.title('Different Allreduce Algorithms among 16 CPUs')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

df = pd.DataFrame({'x':x, 'basic_linear': y1, 'nonoverlapping': y2, 'recursive_doubling': y3, 'ring': y4, 'segmented_ring': y5, 'rabenseifner': y6})

# print(df)
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')
plt.title('Different Allreduce Algorithms among 16 CPUs (size increases power-of-two)')

# style
plt.style.use('seaborn-darkgrid')
 
# create a color palette
palette = plt.get_cmap('Set1')

# multiple line plot

num=0
for column in df.drop('x', axis=1):
    num+=1
    plt.plot(df['x'], df[column], marker=11, color=palette(num), linewidth=1, alpha=0.9, label=column)

# plt.xlim(9.70*1e8, 9.78*1e8)
# plt.ylim(1.015*1e6, 1.04*1e6)

plt.legend()

plt.savefig('imgs/16cpu-pow2-all-algo.png')
plt.show()

# %%
# print(df)
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')
plt.title('Different Allreduce Algorithms among 16 CPUs (size increases power-of-two)')

# style
plt.style.use('seaborn-darkgrid')
 
# create a color palette
palette = plt.get_cmap('Set1')

# multiple line plot

num=0
for column in df.drop('x', axis=1):
    num+=1
    plt.plot(df['x'], df[column], marker=11, color=palette(num), linewidth=1, alpha=0.9, label=column)

plt.xlim(1.75*1e8, 1.85*1e8)
plt.ylim(3.5*1e6, 3.6*1e6)

plt.legend()

plt.savefig('imgs/16cpu-pow2-all-algo-zoomed.png')
plt.show()

# %%
x, y1 = read_algo('data/16cpu/non-power-of-2/algo1.txt')
_, y2 = read_algo('data/16cpu/non-power-of-2/algo2.txt')
_, y3 = read_algo('data/16cpu/non-power-of-2/algo3.txt')
_, y4 = read_algo('data/16cpu/non-power-of-2/algo4.txt')
_, y5 = read_algo('data/16cpu/non-power-of-2/algo5.txt')
_, y6 = read_algo('data/16cpu/non-power-of-2/algo6.txt')

plt.title('Different Allreduce Algorithms among 16 CPUs')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

df = pd.DataFrame({'x':x, 'basic_linear': y1, 'nonoverlapping': y2, 'recursive_doubling': y3, 'ring': y4, 'segmented_ring': y5, 'rabenseifner': y6})

# print(df)
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')
plt.title('Different Allreduce Algorithms among 16 CPUs (size increases non-power-of-two)')

# style
plt.style.use('seaborn-darkgrid')
 
# create a color palette
palette = plt.get_cmap('Set1')

# multiple line plot

num=0
for column in df.drop('x', axis=1):
    num+=1
    plt.plot(df['x'], df[column], marker=11, color=palette(num), linewidth=1, alpha=0.9, label=column)

# plt.xlim(9.70*1e8, 9.78*1e8)
# plt.ylim(1.015*1e6, 1.04*1e6)

plt.legend()
plt.savefig('imgs/16cpu-non2-all-algo.png')
plt.show()

# %%
# print(df)
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')
plt.title('Different Allreduce Algorithms among 16 CPUs (size increases non-power-of-two)')

# style
plt.style.use('seaborn-darkgrid')
 
# create a color palette
palette = plt.get_cmap('Set1')

# multiple line plot

num=0
for column in df.drop('x', axis=1):
    num+=1
    plt.plot(df['x'], df[column], marker=11, color=palette(num), linewidth=1, alpha=0.9, label=column)

plt.xlim(1.75*1e8, 1.85*1e8)
plt.ylim(3.5*1e6, 3.6*1e6)

plt.legend()

plt.savefig('imgs/16cpu-non2-all-algo-zoomed.png')
plt.show()

# %%
print(df)

# %%
# a figure for a fixed large message size, x is number of servers, y is the measured latency.


# algo 1
# message size 195312500

x = np.array([2,4,8,16])
y = np.array([206829.38, 600088.88, 3643461.81, 3870892.67])

plt.plot(x,y,marker=10)
plt.xlabel('number of CPUs')
plt.ylabel('avg latency(us)')
plt.title('Basic Linear Algorithm latency (fixed message size 195MB)')
plt.savefig('imgs/fixed-size-195-algo1.png')
plt.show()

# %%
# a figure for a fixed large message size, x is number of servers, y is the measured latency.


# algo 2
# message size 195312500

x = np.array([2,4,8,16])
y = np.array([211039.65, 612221.39, 3644178.27, 3883515.92])

plt.plot(x,y,marker=10)
plt.xlabel('number of CPUs')
plt.ylabel('avg latency(us)')
plt.title('Non Overlapping Algorithm latency (fixed message size 195MB)')
plt.savefig('imgs/fixed-size-195-algo2.png')
plt.show()

# %%
# a figure for a fixed large message size, x is number of servers, y is the measured latency.


# algo 3
# message size 195312500

x = np.array([2,4,8,16])
y = np.array([206693.36, 604641.38, 3642138.46, 3911527.90])

plt.plot(x,y,marker=10)
plt.xlabel('number of CPUs')
plt.ylabel('avg latency(us)')
plt.title('Recursive Doubling Algorithm latency (fixed message size 195MB)')
plt.savefig('imgs/fixed-size-195-algo3.png')
plt.show()

# %%
# a figure for a fixed large message size, x is number of servers, y is the measured latency.


# algo 4
# message size 195312500

x = np.array([2,4,8,16])
y = np.array([214718.57, 605668.46, 3647108.82, 3856342.03])

plt.plot(x,y,marker=10)
plt.xlabel('number of CPUs')
plt.ylabel('avg latency(us)')
plt.title('Ring Algorithm latency (fixed message size 195MB)')
plt.savefig('imgs/fixed-size-195-algo4.png')
plt.show()

# %%
# a figure for a fixed large message size, x is number of servers, y is the measured latency.


# algo 5
# message size 195312500

x = np.array([2,4,8,16])
y = np.array([210318.70, 604367.58, 3643866.32, 3869682.11])

plt.plot(x,y,marker=10)
plt.xlabel('number of CPUs')
plt.ylabel('avg latency(us)')
plt.title('Segmented Ring Algorithm latency (fixed message size 195MB)')
plt.savefig('imgs/fixed-size-195-algo5.png')
plt.show()

# %%
# a figure for a fixed large message size, x is number of servers, y is the measured latency.


# algo 6
# message size 195312500

x = np.array([2,4,8,16])
y = np.array([206705.74, 601967.27, 3644904.21, 3869897.63])

plt.plot(x,y,marker=10)
plt.xlabel('number of CPUs')
plt.ylabel('avg latency(us)')
plt.title('Rabenseifner\'s Algorithm latency (fixed message size 195MB)')
plt.savefig('imgs/fixed-size-195-algo6.png')
plt.show()

# %%
# a figure for a fixed large message size, x is number of servers, y is the measured latency.


# algo 1 - 6
# message size 195312500

x = np.array([2,4,8,16])
y1 = np.array([206829.38, 600088.88, 3643461.81, 3870892.67])
y2 = np.array([211039.65, 612221.39, 3644178.27, 3883515.92])
y3 = np.array([206693.36, 604641.38, 3642138.46, 3911527.90])
y4 = np.array([214718.57, 605668.46, 3647108.82, 3856342.03])
y5 = np.array([210318.70, 604367.58, 3643866.32, 3869682.11])
y6 = np.array([206705.74, 601967.27, 3644904.21, 3869897.63])

plt.plot(x,y1,marker=10, label='basic_linear')
plt.plot(x,y2,marker=10, label='nonoverlapping')
plt.plot(x,y3,marker=10, label='recursive_doubling')
plt.plot(x,y4,marker=10, label='ring')
plt.plot(x,y5,marker=10, label='segmented_ring')
plt.plot(x,y6,marker=10, label='rabenseifner')




plt.xlabel('number of CPUs')
plt.ylabel('avg latency(us)')
plt.title('Performance Measure of Allreduce Algorithms (fixed message size 195MB)')
plt.legend()
plt.savefig('imgs/fixed-size-195.png')
plt.show()

# %%
# importing the required module 
import matplotlib.pyplot as plt
import numpy as np
  
# number of processes 
x = [2,4,8,16]

# recursive doubling

# 2*(alpha+n*gamma)+N*S*C



# ring algorithm

# 2 * (N-1) * (alpha+S/(NB)) + (N-1)*[(S/N)*C]

# alpha 
# 



# latency time 
y = [3,5,9,17]
  
# plotting the points  
plt.plot(x, y) 
  
# naming the x axis 
plt.xlabel('x - axis') 
# naming the y axis 
plt.ylabel('y - axis') 
  
# giving a title to my graph 
plt.title('My first graph!') 
  
# function to show the plot 
plt.show()

# %%
# a figure for a fixed large message size, x is number of servers, y is the measured latency.


# algo 1 - 6
# message size 134217728
# alpha (latency between two nodes) 36869.18 us

# recursive doubling

x = np.array([2,4,8,16])
y1 = np.array([140919.30, 411059.71, 2482275.29, 2650072.51])
y2 = np.array([142841.95, 411995.91, 2494620.98, 2649909.24])
y3 = np.array([141414.50, 417833.41, 2489576.06, 2645393.20])
y4 = np.array([141647.14, 417309.66, 2508030.37, 2652535.12])
y5 = np.array([141960.10, 418596.73, 2496641.25, 2658183.88])
y6 = np.array([141151.82, 418808.99, 2500568.89, 2656461.54])

plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

plt.plot(x,y1,marker=10, label='basic_linear')
plt.plot(x,y2,marker=10, label='nonoverlapping')
plt.plot(x,y3,marker=10, label='recursive_doubling')
plt.plot(x,y4,marker=10, label='ring')
plt.plot(x,y5,marker=10, label='segmented_ring')
plt.plot(x,y6,marker=10, label='rabenseifner')




plt.xlabel('number of CPUs')
plt.ylabel('avg latency(us)')
plt.title('Performance Measure of Allreduce Algorithms (fixed message size 195MB)')
plt.legend()
plt.savefig('imgs/fixed-size-195.png')
plt.show()

# %%
# a figure for a fixed large message size, x is number of servers, y is the measured latency.


# algo 1 - 6
# message size 268435456
# alpha (latency between two nodes) 74166.14 us

# recursive doubling

x = np.array([2,4,8,16])
y1 = np.array([140919.30, 411059.71, 2482275.29, 2650072.51])
y2 = np.array([142841.95, 411995.91, 2494620.98, 2649909.24])
y3 = np.array([141414.50, 417833.41, 2489576.06, 2645393.20])
y4 = np.array([141647.14, 417309.66, 2508030.37, 2652535.12])
y5 = np.array([210318.70, 604367.58, 3643866.32, 3869682.11])
y6 = np.array([206705.74, 601967.27, 3644904.21, 3869897.63])

plt.plot(x,y1,marker=10, label='basic_linear')
plt.plot(x,y2,marker=10, label='nonoverlapping')
plt.plot(x,y3,marker=10, label='recursive_doubling')
plt.plot(x,y4,marker=10, label='ring')
plt.plot(x,y5,marker=10, label='segmented_ring')
plt.plot(x,y6,marker=10, label='rabenseifner')




plt.xlabel('number of CPUs')
plt.ylabel('avg latency(us)')
plt.title('Performance Measure of Allreduce Algorithms (fixed message size 195MB)')
plt.legend()
plt.savefig('imgs/fixed-size-195.png')
plt.show()

# %%
x = []
y = []

with open('data/22to23-step32.txt') as f:
    for _ in range(4):
        next(f)
    
    for i in f:
        num = i.split()
        x.append(float(num[0]))
        y.append(float(num[1]))
        
# print(x)
# print(y)
        
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

plt.plot(x, y)

plt.xlabel('message size (bytes)')
plt.ylabel('avg latency(us)')
plt.title('Latency between nodes 22 and 23 (4->4K step 32 bytes)')
plt.ylim(0)
plt.xlim(0)

# plt.legend()
plt.savefig('imgs/latency-22-23-step32.png')
plt.show()

slope, intercept = np.polyfit(x,y,1)
print("alpha="+str(intercept))
print("beta="+str(slope))
print("estimated bandwidth="+str(1/slope))
# Out:
# alpha=329.19702203795913
# beta=-0.004088721366292239
# estimated bandwidth=-244.57523768777293

# %%
x = []
y = []

with open('data/22to23-step1000.txt') as f:
    for _ in range(4):
        next(f)
    
    for i in f:
        num = i.split()
        x.append(float(num[0]))
        y.append(float(num[1]))
        
# print(x)
# print(y)
        
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

plt.plot(x, y)

plt.xlabel('message size (bytes)')
plt.ylabel('avg latency(us)')
plt.title('Latency between nodes 22 and 23 (4K->4M step 1Kb)')
plt.ylim(0)
plt.xlim(0)

# plt.legend()
plt.savefig('imgs/latency-22-23-step1000.png')
plt.show()

slope, intercept = np.polyfit(x,y,1)
print("alpha="+str(intercept))
print("beta="+str(slope))
print("estimated bandwidth="+str(1/slope))
# Out:
# alpha=-2986.189846892231
# beta=0.02081874491827738
# estimated bandwidth=48.03363526117614

# %%
x = []
y = []

with open('data/22to23-step1000000.txt') as f:
    for _ in range(4):
        next(f)
    
    for i in f:
        num = i.split()
        x.append(float(num[0]))
        y.append(float(num[1]))
        
# print(x)
# print(y)
        
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

plt.plot(x, y)

plt.xlabel('message size (bytes)')
plt.ylabel('avg latency(us)')
plt.title('Latency between nodes 22 and 23 (4M->512M step 1MB)')
plt.ylim(0)
plt.xlim(0)

# plt.legend()
plt.savefig('imgs/latency-22-23-step1000000.png')
plt.show()

slope, intercept = np.polyfit(x,y,1)
print("alpha="+str(intercept))
print("beta="+str(slope))
print("estimated bandwidth="+str(1/slope))
# Out:
# alpha=16713.2736739783
# beta=0.010627448697194137
# estimated bandwidth=94.09596117495447

# %%
x = []
y = []

with open('data/22to23-step5000000.txt') as f:
    for _ in range(4):
        next(f)
    
    for i in f:
        num = i.split()
        x.append(float(num[0]))
        y.append(float(num[1]))
        
# print(x)
# print(y)
        
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

plt.plot(x, y)

plt.xlabel('message size (bytes)')
plt.ylabel('avg latency(us)')
plt.title('Latency between nodes 22 and 23 (4M->512M step 5MB)')
plt.ylim(0)
plt.xlim(0)

# plt.legend()
plt.savefig('imgs/latency-22-23-step5000000.png')
plt.show()

slope, intercept = np.polyfit(x,y,1)
print("alpha="+str(intercept))
print("beta="+str(slope))
print("estimated bandwidth="+str(1/slope))
# Out:
# alpha=264.1797432100833
# beta=0.00849913042578978
# estimated bandwidth=117.65909568414172

# %%
x = []
y = []

with open('data/10g-latency.txt') as f:
    for _ in range(4):
        next(f)
    
    for i in f:
        num = i.split()
        x.append(float(num[0]))
        y.append(float(num[1]))
        
# print(x)
# print(y)
        
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

plt.plot(x, y)

plt.xlabel('message size (bytes)')
plt.ylabel('avg latency(us)')
plt.title('Latency between nodes 9 and 10 (10Gbps Network Interface)')
plt.ylim(0)
plt.xlim(0)

# plt.legend()
plt.savefig('imgs/10g-latency.png')
plt.show()

slope, intercept = np.polyfit(x,y,1)
print("alpha="+str(intercept))
print("beta="+str(slope))
print("estimated bandwidth="+str(1/slope))




def read_algo_with_head(filename):
    x = []
    y = []

    with open(filename) as f:
        for _ in range(4):
            next(f)
    
        for line in f:
            num = line.split()
            x.append(num[0])
            y.append(num[1])

    x = np.array(x)
    y = np.array(y)

    return x.astype('float'), y.astype('float')

x, y1 = read_algo_with_head('data/new-cluster/allreduce-10g-2cpu-algo1-step1k.txt')


plt.title('Basic Lienar true result vs. estimated (10Gbps, step 1k)')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x, y1, label='algo1:basic_linear', marker=11)


# plt.legend()
# plt.show()


alpha = intercept
beta = slope


# reduce+braodcast
# x2 = [2**x for x in range(2,29)]
y2 = 2*(alpha+beta*x) # ignore computational cost per byte (+ np*message_size*gamma)

plt.plot(x, y2, label='estimated(2*(alpha+beta*x))', marker=11)
plt.legend()

plt.show()

mse = np.square(np.subtract(y1,y2)).mean() 
print('mse is:'+str(mse))
# Out:
# alpha=60.606516751202605
# beta=0.0008989534889913231
# estimated bandwidth=1112.404604071404
# mse is:69584.06209068862

# %%
x, y1 = read_algo_with_head('data/new-cluster/allreduce-10g-16cpu-algo4-step1k.txt')


plt.title('Ring true result vs. estimated (10Gbps, step 1k)')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x, y1, label='algo4:ring', marker=11)


# plt.legend()
# plt.show()


alpha = intercept
beta = slope


# # reduce+braodcast
# # x2 = [2**x for x in range(2,29)]
# y2 = 2*(alpha+beta*x) # ignore computational cost per byte (+ np*message_size*gamma)
num_processes=16

# ring
y2 = 2 * (num_processes-1) * (alpha+(x*beta)/num_processes) # ingore (num_processes-1)*(x*gamma/num_processes)

# plt.plot(x, y2, label='estimated', marker=11)
plt.plot(x, y2, label='estimated(2*(np-1)*(alpha+(beta*x/np)))', marker=11)
plt.legend()

plt.show()

mse = np.square(np.subtract(y1,y2)).mean() 
print('mse is:'+str(mse))
# Out:
# mse is:1275399.3899515

# %%
x, y1 = read_algo_with_head('data/new-cluster/allreduce-10g-16cpu-algo6-step1k.txt')


plt.title('Rabenseifner true result vs. estimated (10Gbps, step 1k)')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x, y1, label='algo6:rabenseifner', marker=11)


# plt.legend()
# plt.show()


alpha = intercept
beta = slope


# # reduce+braodcast
# # x2 = [2**x for x in range(2,29)]
# y2 = 2*(alpha+beta*x) # ignore computational cost per byte (+ np*message_size*gamma)
num_processes=16

# # ring
# y2 = 2 * (num_processes-1) * (alpha+(x*beta)/num_processes) # ingore (num_processes-1)*(x*gamma/num_processes)

# rabenseifner
y2 = 2*np.log2(num_processes)*alpha+2*((num_processes-1)/num_processes)*x*beta

plt.plot(x, y2, label='estimated(2*log2(np)*alpha+2*((np-1)/np)*x*beta)', marker=11)
plt.legend()

plt.show()

mse = np.square(np.subtract(y1,y2)).mean() 
print('mse is:'+str(mse))
# Out:
# mse is:5384299.468454255

# %%
x, y1 = read_algo_with_head('data/new-cluster/allreduce-10g-16cpu-algo3-step1k.txt')


plt.title('Recusive Doubling true result vs. estimated (10Gbps, step 1k)')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x, y1, label='algo3:recursive_doubling', marker=11)


# plt.legend()
# plt.show()


alpha = intercept
beta = slope


# # reduce+braodcast
# # x2 = [2**x for x in range(2,29)]
# y2 = 2*(alpha+beta*x) # ignore computational cost per byte (+ np*message_size*gamma)
num_processes=16

# # ring
# y2 = 2 * (num_processes-1) * (alpha+(x*beta)/num_processes) # ingore (num_processes-1)*(x*gamma/num_processes)

# recursive doubling
y2 = np.log2(num_processes)*(alpha+beta*x)

plt.plot(x, y2, label='estimated(log2(np)*(alpha+beta*x))', marker=11)
plt.legend()

plt.show()

mse = np.square(np.subtract(y1,y2)).mean() 
print('mse is:'+str(mse))
# Out:
# mse is:3455053.9156279257

# %%
x, y1 = read_algo_with_head('data/new-cluster/allreduce-10g-2cpu-algo3-step1k.txt')


plt.title('Some Comparisons between true result vs. estimated (10Gbps, step 1k)')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

x, y1 = read_algo_with_head('data/new-cluster/allreduce-10g-16cpu-algo1-step1k.txt')
# _, y2 = read_algo_with_head('data/new-cluster/allreduce-10g-16cpu-algo2-step1k.txt')
_, y3 = read_algo_with_head('data/new-cluster/allreduce-10g-16cpu-algo3-step1k.txt')
_, y4 = read_algo_with_head('data/new-cluster/allreduce-10g-16cpu-algo4-step1k.txt')
# _, y5 = read_algo_with_head('data/new-cluster/allreduce-10g-16cpu-algo5-step1k.txt')
# _, y6 = read_algo_with_head('data/new-cluster/allreduce-10g-16cpu-algo6-step1k.txt')


# plt.legend()
# plt.show()


alpha = intercept
beta = slope


# reduce+braodcast
y12 = 2*(alpha+beta*x) # ignore computational cost per byte (+ np*message_size*gamma)
num_processes=16

# ring
y42 = 2 * (num_processes-1) * (alpha+(x*beta)/num_processes) # ingore (num_processes-1)*(x*gamma/num_processes)

plt.plot(x, y1, label='algo1:basic_linear', marker=11)
# plt.plot(x, y2, label='algo2:non_overlapping', marker=11)
plt.plot(x, y3, label='algo3:recursive_doubling', marker=11)
plt.plot(x, y4, label='algo4:ring', marker=11)
# plt.plot(x, y5, label='algo5:segmented_ring', marker=11)
# plt.plot(x, y6, label='algo6:rabenseifner', marker=11)

# recursive doubling
y32 = np.log2(num_processes)*(alpha+beta*x)

plt.plot(x, y12, label='reduce+broadcast(2*(alpha+beta*x))', marker=11)
plt.plot(x, y32, label='recursive_doubling(log2(np)*(alpha+beta*x))', marker=11)
plt.plot(x, y42, label='ring(2*(np-1)*(alpha+(beta*x/np)))', marker=11)

plt.legend()

plt.show()

# %%
x = []
y = []

with open('data/100g-latency.txt') as f:
    for _ in range(4):
        next(f)
    
    for i in f:
        num = i.split()
        x.append(float(num[0]))
        y.append(float(num[1]))
        
# print(x)
# print(y)
        
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

plt.plot(x, y)

plt.xlabel('message size (bytes)')
plt.ylabel('avg latency(us)')
plt.title('Latency between nodes 9 and 10 (100Gbps Network Interface)')
plt.ylim(0)
plt.xlim(0)

# plt.legend()
plt.savefig('imgs/100g-latency.png')
plt.show()

slope, intercept = np.polyfit(x,y,1)
print("alpha="+str(intercept))
print("beta="+str(slope))
print("estimated bandwidth="+str(1/slope))
# Out:
# alpha=5.03900798151119
# beta=8.6095571112382e-05
# estimated bandwidth=11614.999320867308

# %%
def read_algo_with_head(filename):
    x = []
    y = []

    with open(filename) as f:
        for _ in range(4):
            next(f)
    
        for line in f:
            num = line.split()
            x.append(num[0])
            y.append(num[1])

    x = np.array(x)
    y = np.array(y)

    return x.astype('float'), y.astype('float')

x, y1 = read_algo_with_head('data/new-cluster/allreduce-10g-2cpu-algo1-step1k.txt')
_, y2 = read_algo_with_head('data/new-cluster/allreduce-10g-2cpu-algo2-step1k.txt')
_, y3 = read_algo_with_head('data/new-cluster/allreduce-10g-2cpu-algo3-step1k.txt')
_, y4 = read_algo_with_head('data/new-cluster/allreduce-10g-2cpu-algo4-step1k.txt')
_, y5 = read_algo_with_head('data/new-cluster/allreduce-10g-2cpu-algo5-step1k.txt')
_, y6 = read_algo_with_head('data/new-cluster/allreduce-10g-2cpu-algo6-step1k.txt')

plt.title('Different Allreduce Algorithms among 2 CPUs (10Gbps, step 1k)')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x, y1, label='algo1:basic_linear', marker=11)
plt.plot(x, y2, label='algo2:non_overlapping', marker=11)
plt.plot(x, y3, label='algo3:recursive_doubling', marker=11)
plt.plot(x, y4, label='algo4:ring', marker=11)
plt.plot(x, y5, label='algo5:segmented_ring', marker=11)
plt.plot(x, y6, label='algo6:rabenseifner', marker=11)

plt.legend()
plt.show()

# %%
x, y1 = read_algo_with_head('data/new-cluster/allreduce-10g-4cpu-algo1-step1k.txt')
_, y2 = read_algo_with_head('data/new-cluster/allreduce-10g-4cpu-algo2-step1k.txt')
_, y3 = read_algo_with_head('data/new-cluster/allreduce-10g-4cpu-algo3-step1k.txt')
_, y4 = read_algo_with_head('data/new-cluster/allreduce-10g-4cpu-algo4-step1k.txt')
_, y5 = read_algo_with_head('data/new-cluster/allreduce-10g-4cpu-algo5-step1k.txt')
_, y6 = read_algo_with_head('data/new-cluster/allreduce-10g-4cpu-algo6-step1k.txt')

plt.title('Different Allreduce Algorithms among 4 CPUs (10Gbps, step 1k)')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x, y1, label='algo1:basic_linear', marker=11)
plt.plot(x, y2, label='algo2:non_overlapping', marker=11)
plt.plot(x, y3, label='algo3:recursive_doubling', marker=11)
plt.plot(x, y4, label='algo4:ring', marker=11)
plt.plot(x, y5, label='algo5:segmented_ring', marker=11)
plt.plot(x, y6, label='algo6:rabenseifner', marker=11)

plt.legend()
plt.show()

# %%
x, y1 = read_algo_with_head('data/new-cluster/allreduce-10g-8cpu-algo1-step1k.txt')
_, y2 = read_algo_with_head('data/new-cluster/allreduce-10g-8cpu-algo2-step1k.txt')
_, y3 = read_algo_with_head('data/new-cluster/allreduce-10g-8cpu-algo3-step1k.txt')
_, y4 = read_algo_with_head('data/new-cluster/allreduce-10g-8cpu-algo4-step1k.txt')
_, y5 = read_algo_with_head('data/new-cluster/allreduce-10g-8cpu-algo5-step1k.txt')
_, y6 = read_algo_with_head('data/new-cluster/allreduce-10g-8cpu-algo6-step1k.txt')

plt.title('Different Allreduce Algorithms among 8 CPUs (10Gbps, step 1k)')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x, y1, label='algo1:basic_linear', marker=11)
plt.plot(x, y2, label='algo2:non_overlapping', marker=11)
plt.plot(x, y3, label='algo3:recursive_doubling', marker=11)
plt.plot(x, y4, label='algo4:ring', marker=11)
plt.plot(x, y5, label='algo5:segmented_ring', marker=11)
plt.plot(x, y6, label='algo6:rabenseifner', marker=11)

plt.legend()
plt.show()

# %%
x, y1 = read_algo_with_head('data/new-cluster/allreduce-10g-16cpu-algo1-step1k.txt')
_, y2 = read_algo_with_head('data/new-cluster/allreduce-10g-16cpu-algo2-step1k.txt')
_, y3 = read_algo_with_head('data/new-cluster/allreduce-10g-16cpu-algo3-step1k.txt')
_, y4 = read_algo_with_head('data/new-cluster/allreduce-10g-16cpu-algo4-step1k.txt')
_, y5 = read_algo_with_head('data/new-cluster/allreduce-10g-16cpu-algo5-step1k.txt')
# _, y6 = read_algo_with_head('data/new-cluster/allreduce-10g-16cpu-algo6-step1k.txt')

plt.title('Different Allreduce Algorithms among 16 CPUs (10Gbps, step 1k)')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x, y1, label='algo1:basic_linear', marker=11)
plt.plot(x, y2, label='algo2:non_overlapping', marker=11)
plt.plot(x, y3, label='algo3:recursive_doubling', marker=11)
plt.plot(x, y4, label='algo4:ring', marker=11)
plt.plot(x, y5, label='algo5:segmented_ring', marker=11)
# plt.plot(x, y6, label='algo6:rabenseifner', marker=11)

plt.legend()
plt.show()

# %%
x, y1 = read_algo_with_head('data/new-cluster/allreduce-100g-16cpu-algo1-step1k.txt')
_, y2 = read_algo_with_head('data/new-cluster/allreduce-100g-16cpu-algo2-step1k.txt')
_, y3 = read_algo_with_head('data/new-cluster/allreduce-100g-16cpu-algo3-step1k.txt')
_, y4 = read_algo_with_head('data/new-cluster/allreduce-100g-16cpu-algo4-step1k.txt')
_, y5 = read_algo_with_head('data/new-cluster/allreduce-100g-16cpu-algo5-step1k.txt')
_, y6 = read_algo_with_head('data/new-cluster/allreduce-100g-16cpu-algo6-step1k.txt')

plt.title('Different Allreduce Algorithms among 16 CPUs (100Gbps, step 1k)')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x, y1, label='algo1:basic_linear', marker=11)
plt.plot(x, y2, label='algo2:non_overlapping', marker=11)
plt.plot(x, y3, label='algo3:recursive_doubling', marker=11)
plt.plot(x, y4, label='algo4:ring', marker=11)
plt.plot(x, y5, label='algo5:segmented_ring', marker=11)
plt.plot(x, y6, label='algo6:rabenseifner', marker=11)

plt.legend()
plt.show()

# %%
x, y1 = read_algo_with_head('data/new-cluster/allreduce-100g-8cpu-algo1-step1k.txt')
_, y2 = read_algo_with_head('data/new-cluster/allreduce-100g-8cpu-algo2-step1k.txt')
_, y3 = read_algo_with_head('data/new-cluster/allreduce-100g-8cpu-algo3-step1k.txt')
_, y4 = read_algo_with_head('data/new-cluster/allreduce-100g-8cpu-algo4-step1k.txt')
_, y5 = read_algo_with_head('data/new-cluster/allreduce-100g-8cpu-algo5-step1k.txt')
_, y6 = read_algo_with_head('data/new-cluster/allreduce-100g-8cpu-algo6-step1k.txt')

plt.title('Different Allreduce Algorithms among 8 CPUs (100Gbps, step 1k)')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x, y1, label='algo1:basic_linear', marker=11)
plt.plot(x, y2, label='algo2:non_overlapping', marker=11)
plt.plot(x, y3, label='algo3:recursive_doubling', marker=11)
plt.plot(x, y4, label='algo4:ring', marker=11)
plt.plot(x, y5, label='algo5:segmented_ring', marker=11)
plt.plot(x, y6, label='algo6:rabenseifner', marker=11)

plt.legend()
plt.show()

# %%
x, y1 = read_algo_with_head('data/new-cluster/allreduce-100g-4cpu-algo1-step1k.txt')
_, y2 = read_algo_with_head('data/new-cluster/allreduce-100g-4cpu-algo2-step1k.txt')
_, y3 = read_algo_with_head('data/new-cluster/allreduce-100g-4cpu-algo3-step1k.txt')
_, y4 = read_algo_with_head('data/new-cluster/allreduce-100g-4cpu-algo4-step1k.txt')
_, y5 = read_algo_with_head('data/new-cluster/allreduce-100g-4cpu-algo5-step1k.txt')
_, y6 = read_algo_with_head('data/new-cluster/allreduce-100g-4cpu-algo6-step1k.txt')

plt.title('Different Allreduce Algorithms among 4 CPUs (100Gbps, step 1k)')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x, y1, label='algo1:basic_linear', marker=11)
plt.plot(x, y2, label='algo2:non_overlapping', marker=11)
plt.plot(x, y3, label='algo3:recursive_doubling', marker=11)
plt.plot(x, y4, label='algo4:ring', marker=11)
plt.plot(x, y5, label='algo5:segmented_ring', marker=11)
plt.plot(x, y6, label='algo6:rabenseifner', marker=11)

plt.legend()
plt.show()

# %%
x = []
y = []

with open('data/lat-10g-step1k.txt') as f:
    for _ in range(4):
        next(f)
    
    for i in f:
        num = i.split()
        x.append(float(num[0]))
        y.append(float(num[1]))
        
# print(x)
# print(y)
        
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

plt.plot(x, y)

plt.xlabel('message size (bytes)')
plt.ylabel('avg latency(us)')
plt.title('Latency between nodes 9 and 10 (10Gbps Network Interface)')
plt.ylim(0)
plt.xlim(0)

# plt.legend()
plt.savefig('imgs/lat-10g-step1k.png')
plt.show()

slope, intercept = np.polyfit(x,y,1)
print("alpha="+str(intercept))
print("beta="+str(slope))
print("estimated bandwidth="+str(1/slope))




def read_algo_with_head(filename):
    x = []
    y = []

    with open(filename) as f:
        for _ in range(4):
            next(f)
    
        for line in f:
            num = line.split()
            x.append(num[0])
            y.append(num[1])

    x = np.array(x)
    y = np.array(y)

    return x.astype('float'), y.astype('float')

x, y1 = read_algo_with_head('data/new-cluster/allreduce-10g-16cpu-algo1-step1k.txt')


plt.title('Basic Lienar true result vs. estimated (10Gbps, step 1k)')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x, y1, label='algo1:basic_linear', marker=11)


# plt.legend()
# plt.show()


alpha = intercept
beta = slope


# reduce+braodcast
# x2 = [2**x for x in range(2,29)]
y2 = 2*(alpha+beta*x) # ignore computational cost per byte (+ np*message_size*gamma)

plt.plot(x, y2, label='estimated(2*(alpha+beta*x))', marker=11)
plt.legend()

plt.show()

mse = np.square(np.subtract(y1,y2)).mean() 
print('mse is:'+str(mse))
# Out:
# alpha=137.7337375954178
# beta=0.0009301203566989708
# estimated bandwidth=1075.1296784311166
# mse is:5447947.441663955

# %%
x, y1 = read_algo_with_head('data/new-cluster/allreduce-10g-16cpu-algo4-step1k.txt')


plt.title('Ring true result vs. estimated (10Gbps, step 1k)')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x, y1, label='algo4:ring', marker=11)


# plt.legend()
# plt.show()


alpha = intercept
beta = slope


# # reduce+braodcast
# # x2 = [2**x for x in range(2,29)]
# y2 = 2*(alpha+beta*x) # ignore computational cost per byte (+ np*message_size*gamma)
num_processes=16

# ring
y2 = 2 * (num_processes-1) * (alpha+(x*beta)/num_processes) # ingore (num_processes-1)*(x*gamma/num_processes)

# plt.plot(x, y2, label='estimated', marker=11)
plt.plot(x, y2, label='estimated(2*(np-1)*(alpha+(beta*x/np)))', marker=11)
plt.legend()

plt.show()

mse = np.square(np.subtract(y1,y2)).mean() 
print('mse is:'+str(mse))
# Out:
# mse is:2818457.9979639533

# %%
x, y1 = read_algo_with_head('data/new-cluster/allreduce-10g-16cpu-algo6-step1k.txt')


plt.title('Rabenseifner true result vs. estimated (10Gbps, step 1k)')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x, y1, label='algo6:rabenseifner', marker=11)


# plt.legend()
# plt.show()


alpha = intercept
beta = slope


# # reduce+braodcast
# # x2 = [2**x for x in range(2,29)]
# y2 = 2*(alpha+beta*x) # ignore computational cost per byte (+ np*message_size*gamma)
num_processes=16

# # ring
# y2 = 2 * (num_processes-1) * (alpha+(x*beta)/num_processes) # ingore (num_processes-1)*(x*gamma/num_processes)

# rabenseifner
y2 = 2*np.log2(num_processes)*alpha+2*((num_processes-1)/num_processes)*x*beta

plt.plot(x, y2, label='estimated(2*log2(np)*alpha+2*((np-1)/np)*x*beta)', marker=11)
plt.legend()

plt.show()

mse = np.square(np.subtract(y1,y2)).mean() 
print('mse is:'+str(mse))
# Out:
# mse is:2919989.3012105804

# %%
x, y1 = read_algo_with_head('data/new-cluster/allreduce-10g-16cpu-algo3-step1k.txt')


plt.title('Recusive Doubling true result vs. estimated (10Gbps, step 1k)')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x, y1, label='algo3:recursive_doubling', marker=11)


# plt.legend()
# plt.show()


alpha = intercept
beta = slope


# # reduce+braodcast
# # x2 = [2**x for x in range(2,29)]
# y2 = 2*(alpha+beta*x) # ignore computational cost per byte (+ np*message_size*gamma)
num_processes=16

# # ring
# y2 = 2 * (num_processes-1) * (alpha+(x*beta)/num_processes) # ingore (num_processes-1)*(x*gamma/num_processes)

# recursive doubling
y2 = np.log2(num_processes)*(alpha+beta*x)

plt.plot(x, y2, label='estimated(log2(np)*(alpha+beta*x))', marker=11)
plt.legend()

plt.show()

mse = np.square(np.subtract(y1,y2)).mean() 
print('mse is:'+str(mse))
# Out:
# mse is:2343733.2307730946

# %%
x = []
y = []

with open('data/lat-10g-step1k-modified.txt') as f:
    for _ in range(4):
        next(f)
    
    for i in f:
        num = i.split()
        x.append(float(num[0]))
        y.append(float(num[1]))
        
# print(x)
# print(y)
        
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

plt.plot(x, y)

plt.xlabel('message size (bytes)')
plt.ylabel('avg latency(us)')
plt.title('Latency between nodes 9 and 10 (10Gbps Network Interface)')
plt.ylim(0)
plt.xlim(0)

# plt.legend()
plt.savefig('imgs/lat-10g-step1k-modified.png')
plt.show()

slope, intercept = np.polyfit(x,y,1)
print("alpha="+str(intercept))
print("beta="+str(slope))
print("estimated bandwidth="+str(1/slope))




def read_algo_with_head(filename):
    x = []
    y = []

    with open(filename) as f:
        for _ in range(4):
            next(f)
    
        for line in f:
            num = line.split()
            x.append(num[0])
            y.append(num[1])

    x = np.array(x)
    y = np.array(y)

    return x.astype('float'), y.astype('float')

x, y1 = read_algo_with_head('data/new-cluster/allreduce-10g-16cpu-algo1-step1k.txt')


plt.title('Basic Lienar true result vs. estimated (10Gbps, step 1k)')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x, y1, label='algo1:basic_linear', marker=11)


# plt.legend()
# plt.show()


alpha = intercept
beta = slope


# reduce+braodcast
# x2 = [2**x for x in range(2,29)]
y2 = 2*(alpha+beta*x) # ignore computational cost per byte (+ np*message_size*gamma)

plt.plot(x, y2, label='estimated(2*(alpha+beta*x))', marker=11)
plt.legend()

plt.show()

mse = np.square(np.subtract(y1,y2)).mean() 
print('mse is:'+str(mse))
# Out:
# alpha=138.6022474746783
# beta=0.0009206472558891672
# estimated bandwidth=1086.1923430534678
# mse is:171958.85634746184

# %%
x, y1 = read_algo_with_head('data/new-cluster/allreduce-10g-16cpu-algo4-step1k.txt')


plt.title('Ring true result vs. estimated (10Gbps, step 1k)')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x, y1, label='algo4:ring', marker=11)


# plt.legend()
# plt.show()


alpha = intercept
beta = slope


# # reduce+braodcast
# # x2 = [2**x for x in range(2,29)]
# y2 = 2*(alpha+beta*x) # ignore computational cost per byte (+ np*message_size*gamma)
num_processes=16

# ring
y2 = 2 * (num_processes-1) * (alpha+(x*beta)/num_processes) # ingore (num_processes-1)*(x*gamma/num_processes)

# plt.plot(x, y2, label='estimated', marker=11)
plt.plot(x, y2, label='estimated(2*(np-1)*(alpha+(beta*x/np)))', marker=11)
plt.legend()

plt.show()

mse = np.square(np.subtract(y1,y2)).mean() 
print('mse is:'+str(mse))
# Out:
# mse is:2873871.162801583

# %%
x, y1 = read_algo_with_head('data/new-cluster/allreduce-10g-16cpu-algo6-step1k.txt')


plt.title('Rabenseifner true result vs. estimated (10Gbps, step 1k)')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x, y1, label='algo6:rabenseifner', marker=11)


# plt.legend()
# plt.show()


alpha = intercept
beta = slope


# # reduce+braodcast
# # x2 = [2**x for x in range(2,29)]
# y2 = 2*(alpha+beta*x) # ignore computational cost per byte (+ np*message_size*gamma)
num_processes=16

# # ring
# y2 = 2 * (num_processes-1) * (alpha+(x*beta)/num_processes) # ingore (num_processes-1)*(x*gamma/num_processes)

# rabenseifner
y2 = 2*np.log2(num_processes)*alpha+2*((num_processes-1)/num_processes)*x*beta

plt.plot(x, y2, label='estimated(2*log2(np)*alpha+2*((np-1)/np)*x*beta)', marker=11)
plt.legend()

plt.show()

mse = np.square(np.subtract(y1,y2)).mean() 
print('mse is:'+str(mse))
# Out:
# mse is:2931960.557243636

# %%
x, y1 = read_algo_with_head('data/new-cluster/allreduce-10g-16cpu-algo3-step1k.txt')


plt.title('Recusive Doubling true result vs. estimated (10Gbps, step 1k)')
plt.xlabel('message size(bytes)')
plt.ylabel('avg latency(us)')

plt.plot(x, y1, label='algo3:recursive_doubling', marker=11)


# plt.legend()
# plt.show()


alpha = intercept
beta = slope


# # reduce+braodcast
# # x2 = [2**x for x in range(2,29)]
# y2 = 2*(alpha+beta*x) # ignore computational cost per byte (+ np*message_size*gamma)
num_processes=16

# # ring
# y2 = 2 * (num_processes-1) * (alpha+(x*beta)/num_processes) # ingore (num_processes-1)*(x*gamma/num_processes)

# recursive doubling
y2 = np.log2(num_processes)*(alpha+beta*x)

plt.plot(x, y2, label='estimated(log2(np)*(alpha+beta*x))', marker=11)
plt.legend()

plt.show()

mse = np.square(np.subtract(y1,y2)).mean() 
print('mse is:'+str(mse))
# Out:
# mse is:2384992.2450635144
